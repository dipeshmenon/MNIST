# %%
pip install idx2numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import idx2numpy


train_images = idx2numpy.convert_from_file('train-images.idx3-ubyte')
train_labels = idx2numpy.convert_from_file('train-labels.idx1-ubyte')


test_images = idx2numpy.convert_from_file('t10k-images.idx3-ubyte')
test_labels = idx2numpy.convert_from_file('t10k-labels.idx1-ubyte')

# %%
import numpy as np


train_images = train_images.reshape(train_images.shape[0], 28*28)
test_images = test_images.reshape(test_images.shape[0], 28*28)

# %%
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# %%
def one_hot_encode(labels, num_classes=10):
    one_hot = np.zeros((labels.size, num_classes))
    one_hot[np.arange(labels.size), labels] = 1
    return one_hot

train_labels = one_hot_encode(train_labels)
test_labels = one_hot_encode(test_labels)

# %%
def plot_learning_curves(history):
    epochs = range(1, len(history['loss']) + 1)

    # Plotting the loss curve
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['loss'], 'b', label='Training loss')
    plt.title('Training Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plotting the accuracy curve
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['accuracy'], 'b', label='Training accuracy')
    plt.title('Training Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage with MNIST:
input_size = 784  # 28x28 images flattened
hidden_size = 128  # Number of neurons in the hidden layer
output_size = 10  # 10 classes for digits 0-9
learning_rate = 0.001
epochs = 25

input_size1 = 784  # 28x28 images flattened
hidden_size1 = 128  # Number of neurons in the hidden layer
output_size1 = 10  # 10 classes for digits 0-9
learning_rate1 = 0.1
epochs1 = 25

nn = NeuralNetwork(input_size, hidden_size, output_size, learning_rate)
nn1 = NeuralNetwork(input_size1, hidden_size1, output_size1, learning_rate1)
history = nn.train(train_images, train_labels, epochs=epochs)  # Use train_images and train_labels
history1 = nn1.train(train_images, train_labels, epochs=epochs1)
# Plot the learning curves
plot_learning_curves(history)
plot_learning_curves(history1)
# Out:
# Epoch 1/25 - Loss: 1.8915, Accuracy: 62.67%
# Epoch 2/25 - Loss: 1.4569, Accuracy: 75.60%
# Epoch 3/25 - Loss: 1.1263, Accuracy: 79.95%
# Epoch 4/25 - Loss: 0.9164, Accuracy: 82.05%
# Epoch 5/25 - Loss: 0.7840, Accuracy: 83.40%
# Epoch 6/25 - Loss: 0.6957, Accuracy: 84.42%
# Epoch 7/25 - Loss: 0.6334, Accuracy: 85.11%
# Epoch 8/25 - Loss: 0.5869, Accuracy: 85.89%
# Epoch 9/25 - Loss: 0.5509, Accuracy: 86.50%
# Epoch 10/25 - Loss: 0.5223, Accuracy: 86.96%
# Epoch 11/25 - Loss: 0.4989, Accuracy: 87.31%
# Epoch 12/25 - Loss: 0.4794, Accuracy: 87.69%
# Epoch 13/25 - Loss: 0.4629, Accuracy: 87.94%
# Epoch 14/25 - Loss: 0.4488, Accuracy: 88.21%
# Epoch 15/25 - Loss: 0.4365, Accuracy: 88.34%
# Epoch 16/25 - Loss: 0.4257, Accuracy: 88.61%
# Epoch 17/25 - Loss: 0.4161, Accuracy: 88.81%
# Epoch 18/25 - Loss: 0.4075, Accuracy: 89.00%
# Epoch 19/25 - Loss: 0.3999, Accuracy: 89.20%
# Epoch 20/25 - Loss: 0.3928, Accuracy: 89.30%
# Epoch 21/25 - Loss: 0.3865, Accuracy: 89.38%
# ...
